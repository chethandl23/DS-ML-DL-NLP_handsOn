# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\data_science_udemy\DATA\Algerian_forest_fires_dataset_UPDATE.csv",header = 1)

# %%
df.head()
# Out:
#    01  06  2012  29  57  18     0  65.7  3.4   7.6  1.3 3.4.1  0.5  not fire
# 0  02  06  2012  29  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4  not fire
# 1  03  06  2012  26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1  not fire
# 2  04  06  2012  25  89  13   2.5  28.6  1.3   6.9    0   1.7    0  not fire
# 3  05  06  2012  27  77  16     0  64.8    3  14.2  1.2   3.9  0.5  not fire
# 4  06  06  2012  31  67  14     0  82.6  5.8  22.2  3.1     7  2.5      fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   01           245 non-null    object
#  1   06           244 non-null    object
#  2   2012         244 non-null    object
#  3   29           244 non-null    object
#  4   57           244 non-null    object
#  5   18           244 non-null    object
#  6   0            244 non-null    object
#  7   65.7         244 non-null    object
#  8   3.4          244 non-null    object
#  9   7.6          244 non-null    object
#  10  1.3          244 non-null    object
#  11  3.4.1        244 non-null    object
#  12  0.5          244 non-null    object
#  13  not fire     243 non-null    object
# dtypes: object(14)
# memory usage: 26.9+ KB

# %%
df.isnull().sum()
# Out:
# 01             0
# 06             1
# 2012           1
# 29             1
# 57             1
# 18             1
# 0              1
# 65.7           1
# 3.4            1
# 7.6            1
# 1.3            1
# 3.4.1          1
# 0.5            1
# not fire       2
# dtype: int64

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   01           245 non-null    object
#  1   06           244 non-null    object
#  2   2012         244 non-null    object
#  3   29           244 non-null    object
#  4   57           244 non-null    object
#  5   18           244 non-null    object
#  6   0            244 non-null    object
#  7   65.7         244 non-null    object
#  8   3.4          244 non-null    object
#  9   7.6          244 non-null    object
#  10  1.3          244 non-null    object
#  11  3.4.1        244 non-null    object
#  12  0.5          244 non-null    object
#  13  not fire     243 non-null    object
#  14  Region       245 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 28.8+ KB

# %%
df[["Region"]]= df[["Region"]].astype(int)

# %%
df.isnull().sum()
# Out:
# 01             0
# 06             1
# 2012           1
# 29             1
# 57             1
# 18             1
# 0              1
# 65.7           1
# 3.4            1
# 7.6            1
# 1.3            1
# 3.4.1          1
# 0.5            1
# not fire       2
# Region         0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#    01  06  2012  29  57  18  ...   7.6  1.3 3.4.1  0.5  not fire    Region
# 0  02  06  2012  29  61  13  ...   7.6    1   3.9  0.4  not fire         0
# 1  03  06  2012  26  82  22  ...   7.1  0.3   2.7  0.1  not fire         0
# 2  04  06  2012  25  89  13  ...   6.9    0   1.7    0  not fire         0
# 3  05  06  2012  27  77  16  ...  14.2  1.2   3.9  0.5  not fire         0
# 4  06  06  2012  31  67  14  ...  22.2  3.1     7  2.5      fire         0
#
# [5 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# 01             0
# 06             0
# 2012           0
# 29             0
# 57             0
# 18             0
# 0              0
# 65.7           0
# 3.4            0
# 7.6            0
# 1.3            0
# 3.4.1          0
# 0.5            0
# not fire       0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      01  06  2012  29  57  18  ...  7.6  1.3 3.4.1  0.5  not fire    Region
# 122  01  06  2012  32  71  12  ...  8.2  0.6   2.8  0.2  not fire         1
#
# [1 rows x 15 columns]

# %%
df = df.drop(122).reset_index(drop = True)

# %%
df.columns
# Out:
# Index(['01', '06', '2012', '29', '57', '18', '0', '65.7', '3.4', '7.6', '1.3',
#        '3.4.1', '0.5', 'not fire   ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['01', '06', '2012', '29', '57', '18', '0', '65.7', '3.4', '7.6', '1.3',
#        '3.4.1', '0.5', 'not fire', 'Region'],
#       dtype='object')

# %%
#change the required cols as integer
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 2
#       1 #change the required cols as integer
# ----> 2 df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %%
objects = [features for features in df.columns if df[features].dtypes =='O']

# %%
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df_copy = df.drop(['day','month','year'], axis=1)

# %%
#encodeing of the categories of classes
df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
##plot denesity plot for all the features
# plt.style.use('seaborn')
df_copy.hist(bins = 50, figsize=(20,15))
plt.show()

# %%
percentage = df_copy['Classes'].value_counts(normalize = True)*100

# %%
plt.figure(figsize=(6,8))
labels = ['NOT FIRE','FIRE']
plt.pie(percentage, labels=labels, autopct='%1.1f%%')
plt.title('Class Distribution')
plt.show()

# %%
#corelation
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_copy.corr(),cmap = 'coolwarm', annot = True)
plt.title('Correlation Heatmap')
plt.show()

# %%
#box plots
plt.figure(figsize=(5,5))
sns.boxplot(data = df_copy[['FWI']])
# Out:
# <Axes: >

# %%
#monthly fire analysis of Bejaia region
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),'not fire','fire')
dfTemp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(10,6))
# sns.set_style("whitegrid")
sns.countplot(x="month", data=dfTemp,hue="Classes",palette="Set3")
plt.title('Monthly Fire Analysis')
# Out:
# Text(0.5, 1.0, 'Monthly Fire Analysis')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'month',y = 'Temperature',data=df,hue='Classes')
plt.title('Temperature vs Classes')
# Out:
# Text(0.5, 1.0, 'Temperature vs Classes')

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
X = df_copy.drop('FWI', axis=1)
y = df_copy['FWI']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 X = df_copy.drop('FWI', axis=1)
#       2 y = df_copy['FWI']
#
# NameError: name 'df_copy' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# NameError: name 'X' is not defined

# %%
#feature selection 
#check for multicolinearity
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
linear = LinearRegression()
ridge = Ridge()
lasso = Lasso()
linear.fit(X_train, y_train)
pread_linear=linear.predict(y)
